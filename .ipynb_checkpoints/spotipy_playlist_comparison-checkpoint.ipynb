# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import pandas as pd
import numpy as np
import configparser

# %%
#Authenticate with config file and spotipy client_id, client_secret, username, values

config = configparser.ConfigParser()
config.read('config_ernflerberg.cfg')
client_id = config.get('SPOTIFY', 'CLIENT_ID')
client_secret = config.get('SPOTIFY', 'CLIENT_SECRET')
username = config.get('SPOTIFY', 'USERNAME')


auth = oauth2.SpotifyClientCredentials(
    client_id=client_id,
    client_secret=client_secret
)

token = auth.get_access_token()
sp = spotipy.Spotify(auth=token)

# %%
def getTrivialInfo(playlistList):
    dfTrivialList=[]
    for playlist in playlistList:
        index=0
        dfTrivial = pd.DataFrame(columns=('SongName', 'SongId', 'SongArtist'), index=np.arange(0, len(playlist['tracks']['items'])))
        for item in playlist['tracks']['items']:
            track = item['track']
            dfTrivial.loc[index]=[track['name'], track['id'], track['artists'][0]['name']]
            index+=1
        dfTrivialList.append(dfTrivial)
    return dfTrivialList

# %%
def getSongList(dfTrivialList):
    songIdsList=[]
    for dfTrivial in dfTrivialList:
        songIds=list(dfTrivial['SongId'])
        songIdsList.append(songIds)
    return songIdsList

# %%
def getFeaturesList(dfTrivialList, songIdsList, columns=('SongName', 'Danceability', 'Energy', 'Loudness', 'Speechiness', 'Acousticness', 'Valence', 'Instrumentalness','Tempo')):
    dfFeaturesList=[]
    for dfTrivial, songIds in zip(dfTrivialList, songIdsList):
        index=0
        audioFeatures = sp.audio_features(tracks=songIds)
        categories=columns[1:]
        dfFeatures = pd.DataFrame(columns=columns, index=np.arange(0, len(songIds)))
        for i, song in enumerate(audioFeatures):
            dfFeatures.loc[index]=[list(dfTrivial['SongName'])[i], song['danceability'], song['energy'], song['loudness'], song['speechiness'], song['acousticness'], song['valence'], song['instrumentalness'], song['tempo']]
            index+=1
        dfFeaturesList.append(dfFeatures)
    return dfFeaturesList

# %%
def getFeaturesToUse(dfFeaturesList, categories=['Danceability','Energy', 'Speechiness', 'Acousticness', 'Valence']):
    featuresToUseList=[]
    for dfFeatures in dfFeaturesList:
        features = dfFeatures[categories]
        featuresToUseList.append(features)
    return featuresToUseList

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from math import pi
import operator

# %%
def featurePreprocessing(song, categories=['Danceability','Energy', 'Speechiness', 'Acousticness', 'Valence']):
    return song[categories]

# %%
playlistDictionary={
                   "Liked": "37i9dQZF1DWY4xHQp97fN6",
                   "Dislike": "37i9dQZF1DWWEJlAGA9gs0"
                   }

# %%
LikedId=playlistDictionary["Liked"]
DislikeId=playlistDictionary["Dislike"]
spotifyUsername='Spotify'

likedplay=sp.user_playlist(spotifyUsername, playlist_id=LikedId)
dislikeplay=sp.user_playlist(spotifyUsername, playlist_id=DislikeId)

# %%
column=('songName', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'valence', 'instrumentalness','tempo')
playlistList=[likedplay, dislikeplay]
n_bins=20
fig, axs = plt.subplots(figsize=(24, 8), nrows=2, ncols=4)
axs=axs.flatten()
dfTrivialList=getTrivialInfo(playlistList)
songIdsList=getSongList(dfTrivialList)
songIds1=songIdsList[0]
songIds2=songIdsList[1]

audioFeatures1 = sp.audio_features(tracks=songIds1)
audioFeatures2 = sp.audio_features(tracks=songIds2)

for song1, song2 in zip(audioFeatures1, audioFeatures2):
    if song1 is None:
        audioFeatures1.remove(song1)
    if song2 is None:
        audioFeatures2.remove(song2)
            
index=0
for feature in column[1:]:
    ax=axs[index]
    ax.set_title(feature)
    featureListToPlot1 = []
    featureListToPlot2 = []

    for song1, song2 in zip(audioFeatures1, audioFeatures2):
        featureListToPlot1.append(song1[feature])
        featureListToPlot2.append(song2[feature])


    sns.distplot(featureListToPlot1, hist=True, bins=n_bins, color = 'blue', hist_kws={'edgecolor':'orange'}, kde_kws={'linewidth': 4}, ax=ax)
    sns.distplot(featureListToPlot2, hist=True, bins=n_bins, color = 'pink', hist_kws={'edgecolor':'yellow'}, kde_kws={'linewidth': 4}, ax=ax)
    index+=1

# %%
def euclideanDistance(data1, data2, weight, length):
    distance = 0
    for x in range(length):
        distance += np.square(weight[x]*(data1[x] - data2[x]))
    return np.sqrt(distance)

def distances(trainingSet, testSong, weight):
    distanceDict = {}
    length = testSong.shape[0]
    for genre, features in trainingSet.items():
        dist = [[euclideanDistance(features.iloc[x], testSong, weight, length), x] for x in range(len(features))]
        distanceDict[genre] = dist
    return distanceDict

# %%
def knn(sortedDistances, k):
    counter={}
    for key in sortedDistances.keys():
        counter[key] =0 
    minKey=''
    minId=0
    neighborKeyAndId=[]
    for i in range(k):
        minValue=5
        for key, value in sortedDistances.items():
            if value[0][0]<minValue:
                minId=value[0][1]
                minKey=key
                minValue = value[0][0]
        del(sortedDistances[minKey][0])
        counter[minKey]=counter[minKey]+1
        neighborKeyAndId.append([minKey, minId])
    return counter, neighborKeyAndId

# %%
playlistList=[likedplay, dislikeplay]

# %%
dfTrivialList=getTrivialInfo(playlistList);
songIdsList=getSongList(dfTrivialList);
dfFeaturesList=getFeaturesList(dfTrivialList, songIdsList, columns=('SongName', 'Danceability', 'Energy', 'Loudness', 'Speechiness', 'Acousticness', 'Valence', 'Instrumentalness','Tempo'))
print(dfFeaturesList[1].iloc[48])
featuresToUseList=getFeaturesToUse(dfFeaturesList, categories=['Danceability','Energy', 'Speechiness', 'Acousticness', 'Valence','Instrumentalness'])
print(featuresToUseList[1])
# Out:
# SongName            Les Baricades Mistérieuses (6e ordre)
# Danceability                                        0.191
# Energy                                             0.0946
# Loudness                                           -25.59
# Speechiness                                        0.0365
# Acousticness                                         0.99
# Valence                                             0.348
# Instrumentalness                                    0.933
# Tempo                                             110.502
# Name: 48, dtype: object
#    Danceability   Energy Speechiness Acousticness Valence Instrumentalness
# 0          0.23   0.0487      0.0412        0.986   0.101            0.945
# 1         0.244   0.0325      0.0457        0.992  0.0406            0.879
# 2         0.244     0.12       0.073        0.972  0.0323            0.768
# 3         0.227   0.0843      0.0384        0.974  0.0737            0.789
# 4         0.235    0.166      0.0347        0.992  0.0356             0.87
# 5         0.135    0.181      0.0361        0.778  0.0378            0.846
# 6         0.295   0.0673      0.0362        0.992  0.0801            0.868
# 7         0.228     0.35      0.0337        0.843   0.181            0.775
# 8         0.362   0.0863      0.0765        0.958  0.0389            0.888
# 9         0.384   0.0414      0.0378        0.992  0.0618            0.897
# 10        0.457    0.316      0.0384        0.965   0.106            0.906
# 11        0.275    0.157      0.0636         0.89   0.304            0.842
# 12        0.242  0.00898      0.0424        0.994  0.0549            0.909
# 13        0.343   0.0209      0.0398        0.987  0.0393            0.922
# 14        0.194   0.0324      0.0382        0.982  0.0596            0.961
# 15        0.398  0.00293      0.0666        0.995  0.0804            0.922
# 16        0.245   0.0942      0.0395        0.985  0.0713            0.893
# 17        0.364    0.189      0.0425        0.964   0.283             0.82
# 18        0.332    0.218      0.0392        0.527   0.538            0.238
# 19         0.38    0.254      0.0365        0.992   0.805            0.926
# 20       0.0811   0.0122      0.0511        0.902  0.0384            0.308
# 21        0.333    0.465      0.0462        0.837   0.641            0.797
# 22       0.0821    0.128      0.0346        0.872  0.0427            0.889
# 23        0.453  0.00715      0.0709        0.995   0.257            0.931
# 24        0.278    0.151       0.042        0.917   0.167            0.122
# 25        0.491   0.0176      0.0644        0.994  0.0901            0.927
# 26        0.134   0.0861      0.0441        0.988  0.0355            0.204
# 27        0.265    0.169       0.036        0.976  0.0399            0.871
# 28        0.233    0.168      0.0341        0.976  0.0635              0.9
# 29        0.513    0.147      0.0845        0.979   0.126            0.907
# ..          ...      ...         ...          ...     ...              ...
# 70        0.308    0.217      0.0429        0.963   0.443            0.858
# 71        0.132   0.0083      0.0616        0.978  0.0391          0.00393
# 72        0.322    0.264      0.0388        0.947   0.176            0.863
# 73         0.24   0.0309      0.0578        0.991  0.0395          0.00052
# 74        0.166   0.0952      0.0491        0.901  0.0388            0.668
# 75        0.205   0.0686      0.0462        0.873  0.0359            0.402
# 76        0.235    0.282      0.0523        0.915   0.103            0.709
# 77        0.279  0.00461      0.0439        0.989   0.039            0.982
# 78        0.164    0.156      0.0423        0.995  0.0396            0.445
# 79        0.146   0.0841      0.0474         0.92   0.117            0.495
# 80        0.293   0.0382      0.0413        0.919  0.0549            0.915
# 81        0.102   0.0733      0.0488        0.974  0.0308            0.859
# 82        0.657    0.102      0.0743         0.95   0.965                0
# 83        0.154   0.0952       0.044        0.866  0.0589            0.539
# 84        0.165    0.139       0.042        0.826  0.0394            0.191
# 85        0.314  0.00627       0.047        0.952   0.326           0.0671
# 86        0.214    0.134      0.0386        0.984   0.219             0.85
# 87        0.303    0.119      0.0386        0.975   0.038             0.88
# 88        0.251    0.304      0.0352        0.967   0.439            0.896
# 89        0.292    0.164      0.0342        0.912   0.284           0.0296
# 90        0.271  0.00954      0.0357        0.985   0.629             0.66
# 91        0.194    0.101       0.048        0.931   0.074            0.714
# 92        0.214    0.165      0.0352        0.985     0.2            0.928
# 93        0.209    0.157      0.0391        0.971  0.0338            0.335
# 94        0.349   0.0817      0.0487         0.97   0.612            0.872
# 95        0.142  0.00336      0.0435        0.949  0.0332            0.318
# 96        0.324   0.0258      0.0515        0.977   0.209         0.000821
# 97        0.103    0.033      0.0496        0.979  0.0416           0.0961
# 98        0.371    0.218      0.0403        0.962   0.413         8.62e-06
# 99        0.196    0.275      0.0405         0.97   0.102            0.468
#
# [100 rows x 6 columns]

# %%
f1= featuresToUseList[0][:35]
f2= featuresToUseList[1][:35]

trainingSet = {'1': f1, '2': f2}
for i in range(len(featuresToUseList)):
    print(i)
    accurate=0
    total=0
    for j in range(35,99):
        distanceList=distances(trainingSet, featuresToUseList[i].iloc[j], [1,1,1,1,1,1])
        print(dfFeaturesList[i].iloc[j])
        sortedDict={}
        for key in distanceList.keys():
            sortedDict[key]=sorted(distanceList[key], key=operator.itemgetter(0))
        counter, neighborKeyAndId = knn(sortedDict, 25)
        prediction=max(counter.items(), key=operator.itemgetter(1))[0]
        if(i+1 == int(prediction)):
            accurate+=1
        total+=1
        print(counter)
    print(float(accurate/total))
# Out:
# 0
# SongName            REEL IT IN (feat. Gucci Mane) - Remix
# Danceability                                        0.779
# Energy                                              0.355
# Loudness                                           -8.971
# Speechiness                                        0.0789
# Acousticness                                       0.0624
# Valence                                             0.362
# Instrumentalness                                        0
# Tempo                                             128.805
# Name: 35, dtype: object
# {'1': 25, '2': 0}
# SongName            Girls Have Fun (feat. G-Eazy & Rich The Kid)
# Danceability                                               0.888
# Energy                                                      0.74
# Loudness                                                  -5.363
# Speechiness                                                0.238
# Acousticness                                             0.00586
# Valence                                                    0.664
# Instrumentalness                                               0
# Tempo                                                    100.003
# Name: 36, dtype: object
# {'1': 25, '2': 0}
# SongName            Bestie (feat. Megan Thee Stallion)
# Danceability                                     0.903
# Energy                                           0.662
# Loudness                                        -4.242
# Speechiness                                      0.286
# Acousticness                                    0.0823
# Valence                                          0.684
# Instrumentalness                                     0
# Tempo                                          101.975
# Name: 37, dtype: object
# {'1': 25, '2': 0}
# SongName            B*tch From Da Souf
# Danceability                     0.863
# Energy                           0.235
# Loudness                       -15.545
# Speechiness                      0.699
# Acousticness                    0.0241
# Valence                          0.399
# Instrumentalness                     0
# Tempo                          150.062
# Name: 38, dtype: object
# {'1': 25, '2': 0}
# SongName            ZEZE (feat. Travis Scott & Offset)
# Danceability                                     0.861
# Energy                                           0.637
# Loudness                                        -5.692
# Speechiness                                       0.24
# Acousticness                                    0.0515
# Valence                                          0.474
# Instrumentalness                              3.35e-06
# Tempo                                           98.044
# Name: 39, dtype: object
# {'1': 25, '2': 0}
# SongName            Momma I Hit A Lick (feat. Kendrick Lamar)
# Danceability                                            0.796
# Energy                                                  0.467
# Loudness                                               -6.293
# Speechiness                                              0.34
# Acousticness                                            0.202
# Valence                                                   0.4
# Instrumentalness                                     3.32e-05
# Tempo                                                 179.974
# Name: 40, dtype: object
# {'1': 25, '2': 0}
# SongName              Money
# Danceability           0.95
# Energy                 0.59
# Loudness             -6.508
# Speechiness            0.29
# Acousticness        0.00534
# Valence               0.219
# Instrumentalness          0
# Tempo               130.003
# Name: 41, dtype: object
# {'1': 25, '2': 0}
# SongName            Wake Up in the Sky
# Danceability                       0.8
# Energy                           0.578
# Loudness                        -5.144
# Speechiness                     0.0485
# Acousticness                   0.00381
# Valence                          0.367
# Instrumentalness                     0
# Tempo                           143.01
# Name: 42, dtype: object
# {'1': 25, '2': 0}
# SongName            Nonstop
# Danceability          0.909
# Energy                0.405
# Loudness             -8.133
# Speechiness            0.14
# Acousticness         0.0306
# Valence               0.455
# Instrumentalness    0.00698
# Tempo               154.984
# Name: 43, dtype: object
# {'1': 25, '2': 0}
# SongName                Big
# Danceability          0.768
# Energy                0.641
# Loudness             -6.197
# Speechiness           0.114
# Acousticness         0.0628
# Valence               0.231
# Instrumentalness          0
# Tempo               144.963
# Name: 44, dtype: object
# {'1': 25, '2': 0}
# SongName            Be Like Me (feat. Lil Wayne)
# Danceability                               0.948
# Energy                                     0.396
# Loudness                                   -8.08
# Speechiness                                0.173
# Acousticness                             0.00335
# Valence                                    0.593
# Instrumentalness                               0
# Tempo                                    104.006
# Name: 45, dtype: object
# {'1': 25, '2': 0}
# SongName            Thotiana (REMIX feat. YG)
# Danceability                             0.92
# Energy                                  0.683
# Loudness                               -4.997
# Speechiness                             0.228
# Acousticness                           0.0369
# Valence                                 0.716
# Instrumentalness                            0
# Tempo                                 104.079
# Name: 46, dtype: object
# {'1': 25, '2': 0}
# SongName            Twerk (feat. Cardi B)
# Danceability                        0.788
# Energy                              0.841
# Loudness                           -4.006
# Speechiness                         0.143
# Acousticness                        0.122
# Valence                             0.493
# Instrumentalness                   0.0011
# Tempo                             190.089
# Name: 47, dtype: object
# {'1': 25, '2': 0}
# SongName            Never Recover (Lil Baby & Gunna, Drake)
# Danceability                                          0.757
# Energy                                                 0.69
# Loudness                                             -5.327
# Speechiness                                           0.282
# Acousticness                                         0.0716
# Valence                                               0.914
# Instrumentalness                                          0
# Tempo                                               132.064
# Name: 48, dtype: object
# {'1': 25, '2': 0}
# SongName            Leave Me Alone
# Danceability                 0.792
# Energy                       0.743
# Loudness                    -2.806
# Speechiness                 0.0851
# Acousticness                 0.107
# Valence                      0.742
# Instrumentalness                 0
# Tempo                      150.024
# Name: 49, dtype: object
# {'1': 25, '2': 0}
# SongName            Taste (feat. Offset)
# Danceability                       0.884
# Energy                             0.559
# Loudness                          -7.442
# Speechiness                         0.12
# Acousticness                      0.0236
# Valence                            0.342
# Instrumentalness                       0
# Tempo                             97.994
# Name: 50, dtype: object
# {'1': 25, '2': 0}
# SongName            Freak Nasty
# Danceability              0.953
# Energy                    0.723
# Loudness                 -6.437
# Speechiness               0.248
# Acousticness            0.00228
# Valence                   0.221
# Instrumentalness              0
# Tempo                    99.969
# Name: 51, dtype: object
# {'1': 25, '2': 0}
# SongName            Praise The Lord (Da Shine) (feat. Skepta)
# Danceability                                             0.85
# Energy                                                  0.569
# Loudness                                               -8.152
# Speechiness                                             0.136
# Acousticness                                           0.0609
# Valence                                                 0.294
# Instrumentalness                                       0.0816
# Tempo                                                   80.02
# Name: 52, dtype: object
# {'1': 25, '2': 0}
# SongName            No Stylist
# Danceability             0.765
# Energy                   0.704
# Loudness                -4.589
# Speechiness              0.127
# Acousticness            0.0215
# Valence                  0.498
# Instrumentalness             0
# Tempo                  147.055
# Name: 53, dtype: object
# {'1': 25, '2': 0}
# SongName            Mo Bamba
# Danceability           0.738
# Energy                 0.629
# Loudness              -4.882
# Speechiness           0.0495
# Acousticness           0.268
# Valence                0.319
# Instrumentalness     0.00114
# Tempo                146.067
# Name: 54, dtype: object
# {'1': 25, '2': 0}
# SongName            Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj
# Danceability                                                 0.743
# Energy                                                       0.339
# Loudness                                                    -7.678
# Speechiness                                                  0.409
# Acousticness                                               0.00582
# Valence                                                      0.118
# Instrumentalness                                                 0
# Tempo                                                      203.927
# Name: 55, dtype: object
# {'1': 25, '2': 0}
# SongName            Drip Too Hard
# Danceability                  0.9
# Energy                      0.653
# Loudness                   -6.962
# Speechiness                 0.289
# Acousticness               0.0945
# Valence                     0.399
# Instrumentalness                0
# Tempo                     112.503
# Name: 56, dtype: object
# {'1': 25, '2': 0}
# SongName            SICKO MODE
# Danceability             0.834
# Energy                    0.73
# Loudness                -3.714
# Speechiness              0.222
# Acousticness           0.00513
# Valence                  0.446
# Instrumentalness             0
# Tempo                  155.008
# Name: 57, dtype: object
# {'1': 25, '2': 0}
# SongName            Salute (feat. French Montana)
# Danceability                                0.768
# Energy                                      0.729
# Loudness                                   -4.079
# Speechiness                                 0.102
# Acousticness                                0.331
# Valence                                     0.588
# Instrumentalness                                0
# Tempo                                     152.038
# Name: 58, dtype: object
# {'1': 25, '2': 0}
# SongName            Ric Flair Drip (& Metro Boomin)
# Danceability                                   0.88
# Energy                                        0.428
# Loudness                                      -8.28
# Speechiness                                   0.206
# Acousticness                                  0.149
# Valence                                       0.333
# Instrumentalness                           5.07e-05
# Tempo                                       100.007
# Name: 59, dtype: object
# {'1': 25, '2': 0}
# SongName            Yes Indeed
# Danceability             0.964
# Energy                   0.346
# Loudness                -9.309
# Speechiness               0.53
# Acousticness             0.035
# Valence                  0.562
# Instrumentalness             0
# Tempo                  119.958
# Name: 60, dtype: object
# {'1': 25, '2': 0}
# SongName            Goin Baby
# Danceability            0.755
# Energy                  0.772
# Loudness               -5.585
# Speechiness               0.4
# Acousticness            0.128
# Valence                 0.678
# Instrumentalness            0
# Tempo                 132.906
# Name: 61, dtype: object
# {'1': 25, '2': 0}
# SongName            Faceshot
# Danceability           0.802
# Energy                 0.833
# Loudness              -4.234
# Speechiness           0.0832
# Acousticness         0.00772
# Valence                0.132
# Instrumentalness           0
# Tempo                 165.97
# Name: 62, dtype: object
# {'1': 25, '2': 0}
# SongName            Shotta Flow
# Danceability              0.888
# Energy                     0.43
# Loudness                 -6.728
# Speechiness               0.588
# Acousticness             0.0786
# Valence                    0.45
# Instrumentalness       1.58e-06
# Tempo                   120.088
# Name: 63, dtype: object
# {'1': 25, '2': 0}
# SongName                 1.5
# Danceability           0.885
# Energy                  0.52
# Loudness              -8.353
# Speechiness            0.359
# Acousticness        0.000244
# Valence                0.306
# Instrumentalness    1.16e-06
# Tempo                 84.022
# Name: 64, dtype: object
# {'1': 25, '2': 0}
# SongName            Big Ole Freak
# Danceability                0.799
# Energy                      0.699
# Loudness                   -7.694
# Speechiness                 0.204
# Acousticness              0.00867
# Valence                     0.627
# Instrumentalness                0
# Tempo                     142.979
# Name: 65, dtype: object
# {'1': 25, '2': 0}
# SongName            Butterfly Doors
# Danceability                  0.925
# Energy                        0.397
# Loudness                    -11.265
# Speechiness                   0.169
# Acousticness                 0.0889
# Valence                       0.429
# Instrumentalness           5.12e-05
# Tempo                       130.008
# Name: 66, dtype: object
# {'1': 25, '2': 0}
# SongName            Alright (feat. Trippie Redd & Preme)
# Danceability                                       0.708
# Energy                                             0.661
# Loudness                                          -5.028
# Speechiness                                         0.11
# Acousticness                                     0.00988
# Valence                                            0.293
# Instrumentalness                                       0
# Tempo                                            155.962
# Name: 67, dtype: object
# {'1': 25, '2': 0}
# SongName            Jumpin on a Jet
# Danceability                  0.824
# Energy                        0.595
# Loudness                     -6.346
# Speechiness                   0.091
# Acousticness                 0.0571
# Valence                       0.157
# Instrumentalness            3.7e-06
# Tempo                       140.039
# Name: 68, dtype: object
# {'1': 25, '2': 0}
# SongName            I'm Not Goin' (feat. Kevin Gates)
# Danceability                                    0.847
# Energy                                           0.54
# Loudness                                       -5.767
# Speechiness                                       0.3
# Acousticness                                    0.171
# Valence                                         0.299
# Instrumentalness                                    0
# Tempo                                         131.009
# Name: 69, dtype: object
# {'1': 25, '2': 0}
# SongName            Bleed It
# Danceability           0.845
# Energy                  0.76
# Loudness              -6.007
# Speechiness            0.357
# Acousticness           0.221
# Valence                0.558
# Instrumentalness           0
# Tempo                101.865
# Name: 70, dtype: object
# {'1': 25, '2': 0}
# SongName            YUSO (feat. Lil Wayne & Saweetie)
# Danceability                                      0.9
# Energy                                          0.649
# Loudness                                       -6.365
# Speechiness                                     0.197
# Acousticness                                  0.00378
# Valence                                         0.658
# Instrumentalness                             2.06e-06
# Tempo                                           93.99
# Name: 71, dtype: object
# {'1': 25, '2': 0}
# SongName            Floss In The Bank
# Danceability                    0.863
# Energy                           0.77
# Loudness                       -3.832
# Speechiness                     0.104
# Acousticness                    0.105
# Valence                         0.798
# Instrumentalness                    0
# Tempo                         103.932
# Name: 72, dtype: object
# {'1': 25, '2': 0}
# SongName            Wit The Shits (W.T.S) [feat. Melii]
# Danceability                                      0.756
# Energy                                            0.814
# Loudness                                         -5.398
# Speechiness                                      0.0416
# Acousticness                                    0.00735
# Valence                                           0.709
# Instrumentalness                                      0
# Tempo                                            146.99
# Name: 73, dtype: object
# {'1': 25, '2': 0}
# SongName                 F&N
# Danceability           0.728
# Energy                 0.628
# Loudness              -4.766
# Speechiness            0.191
# Acousticness            0.01
# Valence                0.393
# Instrumentalness    6.53e-05
# Tempo                 160.94
# Name: 74, dtype: object
# {'1': 25, '2': 0}
# SongName            Live Sheck Wes
# Danceability                 0.781
# Energy                       0.617
# Loudness                     -7.82
# Speechiness                  0.252
# Acousticness              0.000732
# Valence                      0.506
# Instrumentalness            0.0467
# Tempo                      139.973
# Name: 75, dtype: object
# {'1': 25, '2': 0}
# SongName            Ice Me Out - Remix
# Danceability                     0.861
# Energy                           0.474
# Loudness                        -9.773
# Speechiness                      0.347
# Acousticness                    0.0546
# Valence                          0.575
# Instrumentalness              0.000637
# Tempo                          154.982
# Name: 76, dtype: object
# {'1': 25, '2': 0}
# SongName            Identity Theft
# Danceability                 0.938
# Energy                       0.696
# Loudness                    -5.837
# Speechiness                  0.384
# Acousticness                0.0416
# Valence                      0.756
# Instrumentalness                 0
# Tempo                       97.988
# Name: 77, dtype: object
# {'1': 25, '2': 0}
# SongName            On Me (feat. Cardi B)
# Danceability                        0.864
# Energy                              0.666
# Loudness                           -5.525
# Speechiness                         0.234
# Acousticness                       0.0482
# Valence                             0.538
# Instrumentalness                        0
# Tempo                              132.12
# Name: 78, dtype: object
# {'1': 25, '2': 0}
# SongName               Yea!!
# Danceability           0.955
# Energy                 0.691
# Loudness              -6.351
# Speechiness            0.188
# Acousticness        0.000807
# Valence                0.744
# Instrumentalness           0
# Tempo                129.988
# Name: 79, dtype: object
# {'1': 25, '2': 0}
# SongName            Let Me See (feat. Kevin Gates & Lil Skies)
# Danceability                                             0.871
# Energy                                                   0.798
# Loudness                                                -3.775
# Speechiness                                              0.203
# Acousticness                                           0.00229
# Valence                                                  0.527
# Instrumentalness                                             0
# Tempo                                                  140.049
# Name: 80, dtype: object
# {'1': 25, '2': 0}
# SongName            WORKIN ME
# Danceability             0.79
# Energy                  0.629
# Loudness               -4.055
# Speechiness             0.142
# Acousticness            0.182
# Valence                 0.267
# Instrumentalness     7.06e-06
# Tempo                 170.023
# Name: 81, dtype: object
# {'1': 25, '2': 0}
# SongName            I Love It (& Lil Pump)
# Danceability                         0.901
# Energy                               0.522
# Loudness                            -8.304
# Speechiness                           0.33
# Acousticness                        0.0114
# Valence                              0.329
# Instrumentalness                         0
# Tempo                              104.053
# Name: 82, dtype: object
# {'1': 25, '2': 0}
# SongName            Dip (feat. Nicki Minaj)
# Danceability                          0.885
# Energy                                0.543
# Loudness                             -6.338
# Speechiness                             0.2
# Acousticness                         0.0311
# Valence                                0.43
# Instrumentalness                          0
# Tempo                                99.026
# Name: 83, dtype: object
# {'1': 25, '2': 0}
# SongName            Kamikaze
# Danceability           0.792
# Energy                 0.571
# Loudness              -7.539
# Speechiness            0.094
# Acousticness           0.301
# Valence                0.556
# Instrumentalness           0
# Tempo                 99.999
# Name: 84, dtype: object
# {'1': 25, '2': 0}
# SongName            MoshPit (feat. Juice WRLD)
# Danceability                             0.769
# Energy                                   0.627
# Loudness                                -4.064
# Speechiness                              0.262
# Acousticness                             0.394
# Valence                                   0.49
# Instrumentalness                             0
# Tempo                                  157.938
# Name: 85, dtype: object
# {'1': 25, '2': 0}
# SongName            DrIP DrIp Drip (feat. Meek Mill)
# Danceability                                    0.71
# Energy                                         0.814
# Loudness                                      -4.575
# Speechiness                                   0.0561
# Acousticness                                   0.162
# Valence                                        0.714
# Instrumentalness                                   0
# Tempo                                         155.02
# Name: 86, dtype: object
# {'1': 25, '2': 0}
# SongName            FEFE (feat. Nicki Minaj & Murda Beatz)
# Danceability                                         0.931
# Energy                                               0.387
# Loudness                                            -9.127
# Speechiness                                          0.412
# Acousticness                                         0.088
# Valence                                              0.376
# Instrumentalness                                         0
# Tempo                                              125.978
# Name: 87, dtype: object
# {'1': 25, '2': 0}
# SongName            Uptown Vibes (feat. Fabolous & Anuel AA)
# Danceability                                           0.655
# Energy                                                 0.814
# Loudness                                              -3.225
# Speechiness                                           0.0487
# Acousticness                                             0.1
# Valence                                                0.142
# Instrumentalness                                           0
# Tempo                                                 90.997
# Name: 88, dtype: object
# {'1': 25, '2': 0}
# SongName               Neat
# Danceability          0.858
# Energy                  0.8
# Loudness             -4.617
# Speechiness           0.262
# Acousticness          0.109
# Valence               0.665
# Instrumentalness          0
# Tempo               119.996
# Name: 89, dtype: object
# {'1': 25, '2': 0}
# SongName            Who Want The Smoke?
# Danceability                      0.899
# Energy                            0.751
# Loudness                         -4.063
# Speechiness                       0.311
# Acousticness                     0.0732
# Valence                           0.636
# Instrumentalness                      0
# Tempo                           140.029
# Name: 90, dtype: object
# {'1': 25, '2': 0}
# SongName            New Patek
# Danceability             0.85
# Energy                  0.785
# Loudness               -4.963
# Speechiness             0.345
# Acousticness           0.0367
# Valence                 0.718
# Instrumentalness            0
# Tempo                 145.063
# Name: 91, dtype: object
# {'1': 25, '2': 0}
# SongName            Lil Bebe (feat. Lil Baby) - Remix
# Danceability                                    0.856
# Energy                                          0.485
# Loudness                                       -5.519
# Speechiness                                    0.0597
# Acousticness                                   0.0481
# Valence                                        0.0929
# Instrumentalness                                    0
# Tempo                                         136.005
# Name: 92, dtype: object
# {'1': 25, '2': 0}
# SongName            Die Young
# Danceability            0.688
# Energy                  0.656
# Loudness               -5.541
# Speechiness             0.276
# Acousticness            0.218
# Valence                 0.365
# Instrumentalness            0
# Tempo                 160.414
# Name: 93, dtype: object
# {'1': 25, '2': 0}
# SongName            LOSE IT (feat. Lil Baby)
# Danceability                           0.962
# Energy                                 0.573
# Loudness                              -5.924
# Speechiness                            0.308
# Acousticness                          0.0161
# Valence                                0.728
# Instrumentalness                           0
# Tempo                                125.035
# Name: 94, dtype: object
# {'1': 25, '2': 0}
# SongName            NO BYSTANDERS
# Danceability                0.731
# Energy                      0.811
# Loudness                   -3.225
# Speechiness                0.0712
# Acousticness               0.0204
# Valence                     0.426
# Instrumentalness                0
# Tempo                     147.045
# Name: 95, dtype: object
# {'1': 25, '2': 0}
# SongName              I Love
# Danceability           0.671
# Energy                 0.565
# Loudness              -7.401
# Speechiness             0.16
# Acousticness           0.274
# Valence                0.561
# Instrumentalness    6.51e-05
# Tempo                150.014
# Name: 96, dtype: object
# {'1': 25, '2': 0}
# SongName            MIA (feat. Drake)
# Danceability                    0.817
# Energy                          0.539
# Loudness                       -6.349
# Speechiness                    0.0621
# Acousticness                   0.0141
# Valence                         0.158
# Instrumentalness             0.000496
# Tempo                          97.062
# Name: 97, dtype: object
# {'1': 25, '2': 0}
# SongName            Get Dripped (feat. Playboi Carti)
# Danceability                                     0.95
# Energy                                          0.489
# Loudness                                       -8.411
# Speechiness                                     0.462
# Acousticness                                    0.105
# Valence                                         0.919
# Instrumentalness                                    0
# Tempo                                         130.021
# Name: 98, dtype: object
# {'1': 25, '2': 0}
# 1.0
# 1
# SongName            Années de pèlerinage, 1ère année "Suisse", S. ...
# Danceability                                                    0.222
# Energy                                                         0.0119
# Loudness                                                      -32.855
# Speechiness                                                    0.0357
# Acousticness                                                    0.994
# Valence                                                          0.14
# Instrumentalness                                                0.925
# Tempo                                                          72.774
# Name: 35, dtype: object
# {'1': 0, '2': 25}
# SongName            Romeo And Juliet, Op.64 / Act 1: Dance of the ...
# Danceability                                                    0.201
# Energy                                                         0.0628
# Loudness                                                      -20.923
# Speechiness                                                    0.0396
# Acousticness                                                    0.808
# Valence                                                         0.113
# Instrumentalness                                                0.785
# Tempo                                                          78.221
# Name: 36, dtype: object
# {'1': 0, '2': 25}
# SongName            Piano Concerto in G Major, M. 83: 2. Adagio assai
# Danceability                                                    0.128
# Energy                                                         0.0159
# Loudness                                                      -34.595
# Speechiness                                                    0.0399
# Acousticness                                                    0.976
# Valence                                                        0.0373
# Instrumentalness                                                0.949
# Tempo                                                          74.524
# Name: 37, dtype: object
# {'1': 0, '2': 25}
# SongName            Roman nepi tancok (Romanian Folk Dances), BB 6...
# Danceability                                                    0.319
# Energy                                                          0.158
# Loudness                                                      -21.696
# Speechiness                                                    0.0585
# Acousticness                                                    0.991
# Valence                                                         0.163
# Instrumentalness                                                0.882
# Tempo                                                          81.164
# Name: 38, dtype: object
# {'1': 0, '2': 25}
# SongName            String Quartet No. 62 in C Major, Op. 76, No. ...
# Danceability                                                    0.159
# Energy                                                         0.0401
# Loudness                                                      -27.516
# Speechiness                                                    0.0446
# Acousticness                                                    0.984
# Valence                                                         0.106
# Instrumentalness                                                 0.76
# Tempo                                                         106.239
# Name: 39, dtype: object
# {'1': 0, '2': 25}
# SongName            Noches en los jardines de España: I. En el Gen...
# Danceability                                                    0.229
# Energy                                                         0.0569
# Loudness                                                      -20.726
# Speechiness                                                    0.0416
# Acousticness                                                    0.984
# Valence                                                        0.0358
# Instrumentalness                                                0.847
# Tempo                                                         129.258
# Name: 40, dtype: object
# {'1': 0, '2': 25}
# SongName            Il barbiere di Siviglia: Overture (Sinfonia)
# Danceability                                               0.322
# Energy                                                      0.14
# Loudness                                                 -20.747
# Speechiness                                               0.0489
# Acousticness                                               0.906
# Valence                                                    0.285
# Instrumentalness                                           0.759
# Tempo                                                     92.122
# Name: 41, dtype: object
# {'1': 0, '2': 25}
# SongName             Fratres
# Danceability           0.322
# Energy                0.0458
# Loudness             -23.372
# Speechiness           0.0539
# Acousticness           0.938
# Valence                0.037
# Instrumentalness    0.000462
# Tempo                155.221
# Name: 42, dtype: object
# {'1': 0, '2': 25}
# SongName            An der schönen blauen Donau, Op.314
# Danceability                                      0.233
# Energy                                           0.0252
# Loudness                                        -24.824
# Speechiness                                      0.0346
# Acousticness                                      0.975
# Valence                                          0.0936
# Instrumentalness                                  0.604
# Tempo                                            94.736
# Name: 43, dtype: object
# {'1': 0, '2': 25}
# SongName            Le carnaval des animaux, R. 125 (Arr. for 2 Pi...
# Danceability                                                      0.2
# Energy                                                         0.0128
# Loudness                                                      -35.392
# Speechiness                                                    0.0446
# Acousticness                                                     0.99
# Valence                                                        0.0572
# Instrumentalness                                                 0.73
# Tempo                                                          77.847
# Name: 44, dtype: object
# {'1': 0, '2': 25}
# SongName            The Rite of Spring: Part One: Adoration of the...
# Danceability                                                    0.101
# Energy                                                         0.0241
# Loudness                                                      -30.172
# Speechiness                                                    0.0485
# Acousticness                                                    0.947
# Valence                                                        0.0329
# Instrumentalness                                                0.847
# Tempo                                                           87.14
# Name: 45, dtype: object
# {'1': 0, '2': 25}
# SongName            Sonata In D Minor, K.9
# Danceability                         0.389
# Energy                              0.0174
# Loudness                           -32.313
# Speechiness                         0.0393
# Acousticness                         0.994
# Valence                              0.327
# Instrumentalness                     0.892
# Tempo                               93.243
# Name: 46, dtype: object
# {'1': 0, '2': 25}
# SongName            The Unanswered Question
# Danceability                          0.169
# Energy                              0.00183
# Loudness                            -39.286
# Speechiness                          0.0475
# Acousticness                          0.293
# Valence                                0.04
# Instrumentalness                      0.836
# Tempo                               122.417
# Name: 47, dtype: object
# {'1': 0, '2': 25}
# SongName            Les Baricades Mistérieuses (6e ordre)
# Danceability                                        0.191
# Energy                                             0.0946
# Loudness                                           -25.59
# Speechiness                                        0.0365
# Acousticness                                         0.99
# Valence                                             0.348
# Instrumentalness                                    0.933
# Tempo                                             110.502
# Name: 48, dtype: object
# {'1': 0, '2': 25}
# SongName            Symphonie fantastique, Op. 14: Symphonie fanta...
# Danceability                                                    0.356
# Energy                                                          0.207
# Loudness                                                       -17.76
# Speechiness                                                    0.0388
# Acousticness                                                     0.95
# Valence                                                         0.328
# Instrumentalness                                                0.914
# Tempo                                                         146.755
# Name: 49, dtype: object
# {'1': 0, '2': 25}
# SongName            Le Nozze di Figaro, K. 492: Sinfonia
# Danceability                                       0.386
# Energy                                            0.0738
# Loudness                                         -19.369
# Speechiness                                       0.0433
# Acousticness                                       0.839
# Valence                                            0.172
# Instrumentalness                                   0.947
# Tempo                                            142.499
# Name: 50, dtype: object
# {'1': 0, '2': 25}
# SongName            Symphony No. 4 in E-Flat Major, WAB 104, "Roma...
# Danceability                                                   0.0704
# Energy                                                         0.0657
# Loudness                                                      -19.466
# Speechiness                                                    0.0387
# Acousticness                                                    0.948
# Valence                                                        0.0361
# Instrumentalness                                                0.874
# Tempo                                                          61.017
# Name: 51, dtype: object
# {'1': 0, '2': 25}
# SongName            Serse: Aria "Ombra mai fù" (Atto I, scena 1)
# Danceability                                               0.193
# Energy                                                     0.095
# Loudness                                                 -23.482
# Speechiness                                               0.0468
# Acousticness                                               0.935
# Valence                                                   0.0419
# Instrumentalness                                           0.277
# Tempo                                                     107.44
# Name: 52, dtype: object
# {'1': 0, '2': 25}
# SongName            Symphony No. 5 in D Minor, Op. 47: I. Moderato
# Danceability                                                 0.155
# Energy                                                       0.176
# Loudness                                                   -15.716
# Speechiness                                                 0.0374
# Acousticness                                                 0.849
# Valence                                                     0.0372
# Instrumentalness                                             0.818
# Tempo                                                       84.962
# Name: 53, dtype: object
# {'1': 0, '2': 25}
# SongName            Symphony No.4 In E Minor, Op.98: 4. Allegro en...
# Danceability                                                    0.245
# Energy                                                          0.137
# Loudness                                                      -17.533
# Speechiness                                                    0.0379
# Acousticness                                                    0.966
# Valence                                                         0.066
# Instrumentalness                                                0.813
# Tempo                                                         139.998
# Name: 54, dtype: object
# {'1': 0, '2': 25}
# SongName            Violin Concerto BWV 1042 in E Major: Violin Co...
# Danceability                                                    0.441
# Energy                                                          0.319
# Loudness                                                       -13.99
# Speechiness                                                    0.0392
# Acousticness                                                    0.829
# Valence                                                         0.671
# Instrumentalness                                                    0
# Tempo                                                          99.419
# Name: 55, dtype: object
# {'1': 16, '2': 9}
# SongName            Nocturne No.1 in B flat minor, Op.9 No.1
# Danceability                                           0.342
# Energy                                                0.0179
# Loudness                                             -24.846
# Speechiness                                           0.0387
# Acousticness                                           0.982
# Valence                                               0.0382
# Instrumentalness                                       0.906
# Tempo                                                 61.757
# Name: 56, dtype: object
# {'1': 0, '2': 25}
# SongName            Appalachian Spring: VII. Doppio movimento
# Danceability                                            0.186
# Energy                                                  0.124
# Loudness                                              -15.271
# Speechiness                                            0.0434
# Acousticness                                            0.978
# Valence                                                 0.248
# Instrumentalness                                        0.865
# Tempo                                                  77.903
# Name: 57, dtype: object
# {'1': 0, '2': 25}
# SongName            Piano Sonata No. 14 in C-Sharp Minor, Op. 27 N...
# Danceability                                                    0.244
# Energy                                                         0.0021
# Loudness                                                      -41.044
# Speechiness                                                    0.0417
# Acousticness                                                    0.995
# Valence                                                         0.187
# Instrumentalness                                                 0.86
# Tempo                                                          64.364
# Name: 58, dtype: object
# {'1': 0, '2': 25}
# SongName            Symphony No.5 in E flat, Op.82: 3. Allegro molto
# Danceability                                                   0.144
# Energy                                                        0.0868
# Loudness                                                     -23.338
# Speechiness                                                   0.0387
# Acousticness                                                   0.891
# Valence                                                       0.0737
# Instrumentalness                                               0.904
# Tempo                                                         94.463
# Name: 59, dtype: object
# {'1': 0, '2': 25}
# SongName            Symphony No. 5 in E Minor, Op. 64: IV. Andante...
# Danceability                                                    0.279
# Energy                                                          0.302
# Loudness                                                      -15.506
# Speechiness                                                    0.0396
# Acousticness                                                    0.959
# Valence                                                         0.167
# Instrumentalness                                                0.898
# Tempo                                                         139.347
# Name: 60, dtype: object
# {'1': 0, '2': 25}
# SongName            Symphony No. 92 in G Major, Hob. I:92 - "Oxfor...
# Danceability                                                    0.416
# Energy                                                         0.0509
# Loudness                                                      -22.124
# Speechiness                                                    0.0478
# Acousticness                                                    0.931
# Valence                                                         0.353
# Instrumentalness                                               0.0778
# Tempo                                                         126.779
# Name: 61, dtype: object
# {'1': 0, '2': 25}
# SongName            Violin Sonata in A Major, FWV 8: Allegretto po...
# Danceability                                                     0.25
# Energy                                                          0.135
# Loudness                                                      -18.615
# Speechiness                                                    0.0488
# Acousticness                                                    0.958
# Valence                                                         0.179
# Instrumentalness                                               0.0349
# Tempo                                                          94.404
# Name: 62, dtype: object
# {'1': 0, '2': 25}
# SongName            Harmonium (for large orchestra and chorus): Pa...
# Danceability                                                    0.219
# Energy                                                         0.0937
# Loudness                                                      -25.246
# Speechiness                                                    0.0434
# Acousticness                                                    0.974
# Valence                                                        0.0347
# Instrumentalness                                                0.897
# Tempo                                                         124.612
# Name: 63, dtype: object
# {'1': 0, '2': 25}
# SongName            Symphony No. 9 in D Major: IV. Adagio - Sehr l...
# Danceability                                                    0.137
# Energy                                                         0.0292
# Loudness                                                      -25.755
# Speechiness                                                    0.0425
# Acousticness                                                    0.805
# Valence                                                        0.0309
# Instrumentalness                                                0.298
# Tempo                                                          81.113
# Name: 64, dtype: object
# {'1': 0, '2': 25}
# SongName            Verklärte Nacht, Op. 4
# Danceability                         0.168
# Energy                               0.144
# Loudness                           -18.636
# Speechiness                         0.0422
# Acousticness                         0.965
# Valence                             0.0357
# Instrumentalness                     0.767
# Tempo                               87.983
# Name: 65, dtype: object
# {'1': 0, '2': 25}
# SongName            Lieutenant Kijé, Op. 60: II. Romance
# Danceability                                       0.187
# Energy                                            0.0169
# Loudness                                         -30.742
# Speechiness                                       0.0359
# Acousticness                                       0.943
# Valence                                           0.0843
# Instrumentalness                                   0.891
# Tempo                                            103.833
# Name: 66, dtype: object
# {'1': 0, '2': 25}
# SongName            Shostakovich: Piano Quintet in G Minor, Op. 57...
# Danceability                                                     0.24
# Energy                                                          0.275
# Loudness                                                      -14.968
# Speechiness                                                    0.0398
# Acousticness                                                    0.954
# Valence                                                         0.196
# Instrumentalness                                                0.164
# Tempo                                                          88.166
# Name: 67, dtype: object
# {'1': 0, '2': 25}
# SongName            Cello Concerto In B Minor, Op.104, B. 191: 1. ...
# Danceability                                                    0.231
# Energy                                                          0.133
# Loudness                                                      -20.274
# Speechiness                                                    0.0437
# Acousticness                                                    0.963
# Valence                                                        0.0564
# Instrumentalness                                                0.659
# Tempo                                                         122.239
# Name: 68, dtype: object
# {'1': 0, '2': 25}
# SongName            Messiah, HWV 56, Pt. 1: For unto us a child is...
# Danceability                                                    0.511
# ...
# Valence                                            0.0391
# Instrumentalness                                  0.00393
# Tempo                                              80.347
# Name: 71, dtype: object
# {'1': 0, '2': 25}
# SongName            The Planets, Op.32/H.125: Jupiter, the Bringer...
# Danceability                                                    0.322
# Energy                                                          0.264
# Loudness                                                      -13.969
# Speechiness                                                    0.0388
# Acousticness                                                    0.947
# Valence                                                         0.176
# Instrumentalness                                                0.863
# Tempo                                                         132.463
# Name: 72, dtype: object
# {'1': 0, '2': 25}
# SongName            Antiphon, O quam mirabilis est
# Danceability                                  0.24
# Energy                                      0.0309
# Loudness                                   -27.569
# Speechiness                                 0.0578
# Acousticness                                 0.991
# Valence                                     0.0395
# Instrumentalness                           0.00052
# Tempo                                       83.457
# Name: 73, dtype: object
# {'1': 0, '2': 25}
# SongName            Symphony No. 4
# Danceability                 0.166
# Energy                      0.0952
# Loudness                   -23.083
# Speechiness                 0.0491
# Acousticness                 0.901
# Valence                     0.0388
# Instrumentalness             0.668
# Tempo                       64.276
# Name: 74, dtype: object
# {'1': 0, '2': 25}
# SongName            Meditation: Méditation from Thaïs
# Danceability                                    0.205
# Energy                                         0.0686
# Loudness                                      -23.415
# Speechiness                                    0.0462
# Acousticness                                    0.873
# Valence                                        0.0359
# Instrumentalness                                0.402
# Tempo                                          90.779
# Name: 75, dtype: object
# {'1': 0, '2': 25}
# SongName            Scheherezade, Op. 35: IV. The Festival of Bagd...
# Danceability                                                    0.235
# Energy                                                          0.282
# Loudness                                                      -15.247
# Speechiness                                                    0.0523
# Acousticness                                                    0.915
# Valence                                                         0.103
# Instrumentalness                                                0.709
# Tempo                                                          89.451
# Name: 76, dtype: object
# {'1': 0, '2': 25}
# SongName            Orfeo ed Euridice, Wq. 30 - Arranged Sgambati ...
# Danceability                                                    0.279
# Energy                                                        0.00461
# Loudness                                                      -36.886
# Speechiness                                                    0.0439
# Acousticness                                                    0.989
# Valence                                                         0.039
# Instrumentalness                                                0.982
# Tempo                                                          69.813
# Name: 77, dtype: object
# {'1': 0, '2': 25}
# SongName            Missa Papae Marcelli: Kyrie
# Danceability                              0.164
# Energy                                    0.156
# Loudness                                -20.916
# Speechiness                              0.0423
# Acousticness                              0.995
# Valence                                  0.0396
# Instrumentalness                          0.445
# Tempo                                   136.432
# Name: 78, dtype: object
# {'1': 0, '2': 25}
# SongName            String Quartet No.2 in D: 3. Notturno
# Danceability                                        0.146
# Energy                                             0.0841
# Loudness                                          -22.412
# Speechiness                                        0.0474
# Acousticness                                         0.92
# Valence                                             0.117
# Instrumentalness                                    0.495
# Tempo                                              76.471
# Name: 79, dtype: object
# {'1': 0, '2': 25}
# SongName            Concierto de Aranjuez for Guitar and Orchestra...
# Danceability                                                    0.293
# Energy                                                         0.0382
# Loudness                                                      -21.783
# Speechiness                                                    0.0413
# Acousticness                                                    0.919
# Valence                                                        0.0549
# Instrumentalness                                                0.915
# Tempo                                                         110.257
# Name: 80, dtype: object
# {'1': 0, '2': 25}
# SongName            Barber: Adagio for Strings
# Danceability                             0.102
# Energy                                  0.0733
# Loudness                               -24.133
# Speechiness                             0.0488
# Acousticness                             0.974
# Valence                                 0.0308
# Instrumentalness                         0.859
# Tempo                                   73.954
# Name: 81, dtype: object
# {'1': 0, '2': 25}
# SongName            light moving
# Danceability               0.657
# Energy                     0.102
# Loudness                 -30.666
# Speechiness               0.0743
# Acousticness                0.95
# Valence                    0.965
# Instrumentalness               0
# Tempo                    101.978
# Name: 82, dtype: object
# {'1': 14, '2': 11}
# SongName            Violin Concerto No.1 in G minor, Op.26: 1. Vor...
# Danceability                                                    0.154
# Energy                                                         0.0952
# Loudness                                                      -21.534
# Speechiness                                                     0.044
# Acousticness                                                    0.866
# Valence                                                        0.0589
# Instrumentalness                                                0.539
# Tempo                                                          72.495
# Name: 83, dtype: object
# {'1': 0, '2': 25}
# SongName            Les Boréades, RCT 31, Acte IV, Scène IV: Entré...
# Danceability                                                    0.165
# Energy                                                          0.139
# Loudness                                                      -18.908
# Speechiness                                                     0.042
# Acousticness                                                    0.826
# Valence                                                        0.0394
# Instrumentalness                                                0.191
# Tempo                                                         130.285
# Name: 84, dtype: object
# {'1': 0, '2': 25}
# SongName            Concerto In G Major TWV 40:201, For 4 Violins ...
# Danceability                                                    0.314
# Energy                                                        0.00627
# Loudness                                                      -24.406
# Speechiness                                                     0.047
# Acousticness                                                    0.952
# Valence                                                         0.326
# Instrumentalness                                               0.0671
# Tempo                                                         109.756
# Name: 85, dtype: object
# {'1': 0, '2': 25}
# SongName            The Heart Asks Pleasure First
# Danceability                                0.214
# Energy                                      0.134
# Loudness                                  -25.264
# Speechiness                                0.0386
# Acousticness                                0.984
# Valence                                     0.219
# Instrumentalness                             0.85
# Tempo                                     136.645
# Name: 86, dtype: object
# {'1': 0, '2': 25}
# SongName            Piano Concerto in A Minor, Op.16: I. Allegro m...
# Danceability                                                    0.303
# Energy                                                          0.119
# Loudness                                                      -18.055
# Speechiness                                                    0.0386
# Acousticness                                                    0.975
# Valence                                                         0.038
# Instrumentalness                                                 0.88
# Tempo                                                          94.868
# Name: 87, dtype: object
# {'1': 0, '2': 25}
# SongName            Étude in D-sharp minor, Op. 8, No. 12
# Danceability                                        0.251
# Energy                                              0.304
# Loudness                                          -16.228
# Speechiness                                        0.0352
# Acousticness                                        0.967
# Valence                                             0.439
# Instrumentalness                                    0.896
# Tempo                                             166.953
# Name: 88, dtype: object
# {'1': 0, '2': 25}
# SongName            Symphony No. 1 in D major, Wq. 183/1: Symphony...
# Danceability                                                    0.292
# Energy                                                          0.164
# Loudness                                                      -17.792
# Speechiness                                                    0.0342
# Acousticness                                                    0.912
# Valence                                                         0.284
# Instrumentalness                                               0.0296
# Tempo                                                          149.46
# Name: 89, dtype: object
# {'1': 1, '2': 24}
# SongName            Musica ricercata: No. 7, Cantabile, molto legato
# Danceability                                                   0.271
# Energy                                                       0.00954
# Loudness                                                     -35.478
# Speechiness                                                   0.0357
# Acousticness                                                   0.985
# Valence                                                        0.629
# Instrumentalness                                                0.66
# Tempo                                                        126.358
# Name: 90, dtype: object
# {'1': 0, '2': 25}
# SongName            String Quartet No. 1 'Kreutzer Sonata': String...
# Danceability                                                    0.194
# Energy                                                          0.101
# Loudness                                                      -21.772
# Speechiness                                                     0.048
# Acousticness                                                    0.931
# Valence                                                         0.074
# Instrumentalness                                                0.714
# Tempo                                                           91.74
# Name: 91, dtype: object
# {'1': 0, '2': 25}
# SongName            Auf dem Wasser zu singen, D.774 - Transcriptio...
# Danceability                                                    0.214
# Energy                                                          0.165
# Loudness                                                      -20.702
# Speechiness                                                    0.0352
# Acousticness                                                    0.985
# Valence                                                           0.2
# Instrumentalness                                                0.928
# Tempo                                                         101.073
# Name: 92, dtype: object
# {'1': 0, '2': 25}
# SongName            Violin Concerto - 'To the Memory of an Angel':...
# Danceability                                                    0.209
# Energy                                                          0.157
# Loudness                                                      -18.821
# Speechiness                                                    0.0391
# Acousticness                                                    0.971
# Valence                                                        0.0338
# Instrumentalness                                                0.335
# Tempo                                                          106.24
# Name: 93, dtype: object
# {'1': 0, '2': 25}
# SongName            The Frog Galliard (P 23a)
# Danceability                            0.349
# Energy                                 0.0817
# Loudness                              -30.501
# Speechiness                            0.0487
# Acousticness                             0.97
# Valence                                 0.612
# Instrumentalness                        0.872
# Tempo                                 105.606
# Name: 94, dtype: object
# {'1': 0, '2': 25}
# SongName            Turangalîla Symphonie: 6. Jardin du sommeil d'...
# Danceability                                                    0.142
# Energy                                                        0.00336
# Loudness                                                       -42.32
# Speechiness                                                    0.0435
# Acousticness                                                    0.949
# Valence                                                        0.0332
# Instrumentalness                                                0.318
# Tempo                                                         100.298
# Name: 95, dtype: object
# {'1': 0, '2': 25}
# SongName            Early One Morning
# Danceability                    0.324
# Energy                         0.0258
# Loudness                      -27.621
# Speechiness                    0.0515
# Acousticness                    0.977
# Valence                         0.209
# Instrumentalness             0.000821
# Tempo                         114.186
# Name: 96, dtype: object
# {'1': 0, '2': 25}
# SongName            Bachianas brasileiras No.5, W. 389: 1. Aria (C...
# Danceability                                                    0.103
# Energy                                                          0.033
# Loudness                                                      -23.661
# Speechiness                                                    0.0496
# Acousticness                                                    0.979
# Valence                                                        0.0416
# Instrumentalness                                               0.0961
# Tempo                                                           61.97
# Name: 97, dtype: object
# {'1': 0, '2': 25}
# SongName            Rigoletto / Act 3: "La donna è mobile"
# Danceability                                         0.371
# Energy                                               0.218
# Loudness                                           -13.076
# Speechiness                                         0.0403
# Acousticness                                         0.962
# Valence                                              0.413
# Instrumentalness                                  8.62e-06
# Tempo                                              117.824
# Name: 98, dtype: object
# {'1': 4, '2': 21}
# 0.96875
